# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# no keys required for crypto data
client = CryptoHistoricalDataClient()

request_params = CryptoBarsRequest(
    symbol_or_symbols=["BTC/USD", "ETH/USD"],
    timeframe=TimeFrame.Day,
    start="2022-07-01"
)

bars = client.get_crypto_bars(request_params)
bars
# Out:
# {   'data': {   'BTC/USD': [   {   'close': 19256.75,
#                                    'high': 20896.36,
#                                    'low': 18940.0,
#                                    'open': 19935.53,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 1, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 148392.0,
#                                    'volume': 9747.183616,
#                                    'vwap': 19619.5931898458},
#                                {   'close': 19226.53,
#                                    'high': 19441.9,
#                                    'low': 18956.79,
#                                    'open': 19261.58,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 2, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 66000.0,
#                                    'volume': 3913.931431,
#                                    'vwap': 19214.4135693056},
#                                {   'close': 19290.68,
#                                    'high': 19625.32,
#                                    'low': 18752.98,
#                                    'open': 19227.69,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 3, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 94793.0,
#                                    'volume': 3275.136164,
#                                    'vwap': 19160.0739040402},
#                                {   'close': 20212.61,
#                                    'high': 20320.0,
#                                    'low': 19034.13,
#                                    'open': 19292.88,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 4, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 213657.0,
#                                    'volume': 6404.379456,
#                                    'vwap': 19653.9721563378},
#                                {   'close': 20157.22,
#                                    'high': 20728.5,
#                                    'low': 19281.37,
#                                    'open': 20212.61,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 5, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 270041.0,
#                                    'volume': 9137.287715,
#                                    'vwap': 19980.4839124668},
#                                {   'close': 20544.74,
#                                    'high': 20650.0,
#                                    'low': 19734.34,
#                                    'open': 20155.19,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 6, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 278829.0,
#                                    'volume': 8316.786804,
#                                    'vwap': 20171.6154959302},
#                                {   'close': 21615.25,
#                                    'high': 21835.0,
#                                    'low': 20233.0,
#                                    'open': 20544.75,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 7, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 262343.0,
#                                    'volume': 8114.680857,
#                                    'vwap': 20902.9193210776},
#                                {   'close': 21595.99,
#                                    'high': 22500.59,
#                                    'low': 21172.41,
#                                    'open': 21619.66,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 8, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 287973.0,
#                                    'volume': 8915.04836,
#                                    'vwap': 21757.0666116903},
#                                {   'close': 21581.42,
#                                    'high': 21980.88,
#                                    'low': 21313.66,
#                                    'open': 21590.64,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 9, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 226793.0,
#                                    'volume': 5401.384965,
#                                    'vwap': 21612.057312417},
#                                {   'close': 20844.56,
#                                    'high': 21593.11,
#                                    'low': 20632.99,
#                                    'open': 21581.54,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 10, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 192493.0,
#                                    'volume': 4889.43878,
#                                    'vwap': 21113.6534754388},
#                                {   'close': 19946.01,
#                                    'high': 20851.78,
#                                    'low': 19865.21,
#                                    'open': 20848.48,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 11, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 225825.0,
#                                    'volume': 7244.704395,
#                                    'vwap': 20460.2332063008},
#                                {   'close': 19308.37,
#                                    'high': 20044.29,
#                                    'low': 19226.0,
#                                    'open': 19942.06,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 12, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 209076.0,
#                                    'volume': 7402.306533,
#                                    'vwap': 19741.5056623835},
#                                {   'close': 20219.7,
#                                    'high': 20326.63,
#                                    'low': 18900.0,
#                                    'open': 19308.37,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 13, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 238246.0,
#                                    'volume': 9517.12487,
#                                    'vwap': 19576.5457280893},
#                                {   'close': 20576.51,
#                                    'high': 20879.17,
#                                    'low': 19588.9,
#                                    'open': 20220.27,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 14, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 227163.0,
#                                    'volume': 10528.844911,
#                                    'vwap': 20169.2335203149},
#                                {   'close': 20825.45,
#                                    'high': 21191.81,
#                                    'low': 20367.46,
#                                    'open': 20576.5,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 15, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 195890.0,
#                                    'volume': 7202.691179,
#                                    'vwap': 20800.5408429089},
#                                {   'close': 21190.34,
#                                    'high': 21575.34,
#                                    'low': 20477.03,
#                                    'open': 20824.72,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 16, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 153794.0,
#                                    'volume': 4799.276054,
#                                    'vwap': 20984.6920608912},
#                                {   'close': 20798.5,
#                                    'high': 21657.49,
#                                    'low': 20751.81,
#                                    'open': 21187.66,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 17, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 165462.0,
#                                    'volume': 4969.886569,
#                                    'vwap': 21219.9378764024},
#                                {   'close': 22422.05,
#                                    'high': 22757.94,
#                                    'low': 20754.57,
#                                    'open': 20796.23,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 18, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 218568.0,
#                                    'volume': 11288.740977,
#                                    'vwap': 21935.3906246325},
#                                {   'close': 23392.19,
#                                    'high': 23800.0,
#                                    'low': 21583.97,
#                                    'open': 22433.81,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 19, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 274122.0,
#                                    'volume': 15605.613865,
#                                    'vwap': 22669.6516178149},
#                                {   'close': 23225.6,
#                                    'high': 24275.94,
#                                    'low': 22915.0,
#                                    'open': 23392.18,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 20, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 273568.0,
#                                    'volume': 15777.664581,
#                                    'vwap': 23577.3609187858},
#                                {   'close': 23151.58,
#                                    'high': 23431.71,
#                                    'low': 22342.28,
#                                    'open': 23223.33,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 21, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 190756.0,
#                                    'volume': 10100.976224,
#                                    'vwap': 22921.9504487259},
#                                {   'close': 22684.3,
#                                    'high': 23758.46,
#                                    'low': 22507.15,
#                                    'open': 23154.89,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 22, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 172986.0,
#                                    'volume': 7196.81416,
#                                    'vwap': 23190.7686019052},
#                                {   'close': 22449.31,
#                                    'high': 23000.0,
#                                    'low': 21950.0,
#                                    'open': 22688.58,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 23, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 87283.0,
#                                    'volume': 4638.197531,
#                                    'vwap': 22433.5702489088},
#                                {   'close': 22591.28,
#                                    'high': 23020.0,
#                                    'low': 22266.0,
#                                    'open': 22456.0,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 24, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 111809.0,
#                                    'volume': 5182.093999,
#                                    'vwap': 22672.2700831173},
#                                {   'close': 21316.22,
#                                    'high': 22670.5,
#                                    'low': 21258.06,
#                                    'open': 22585.88,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 25, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 148095.0,
#                                    'volume': 7308.42268,
#                                    'vwap': 21923.3534050805},
#                                {   'close': 21255.55,
#                                    'high': 21348.34,
#                                    'low': 20714.96,
#                                    'open': 21309.85,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 26, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 126233.0,
#                                    'volume': 5882.288373,
#                                    'vwap': 21031.532139262},
#                                {   'close': 22958.18,
#                                    'high': 23113.54,
#                                    'low': 21041.4,
#                                    'open': 21258.08,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 27, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 205058.0,
#                                    'volume': 9128.985083,
#                                    'vwap': 21984.5187572279},
#                                {   'close': 23849.44,
#                                    'high': 24199.98,
#                                    'low': 22583.33,
#                                    'open': 22961.96,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 28, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 183692.0,
#                                    'volume': 10025.430938,
#                                    'vwap': 23352.4072935564},
#                                {   'close': 23782.99,
#                                    'high': 24439.0,
#                                    'low': 23433.85,
#                                    'open': 23852.08,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 29, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 162639.0,
#                                    'volume': 8152.005981,
#                                    'vwap': 23869.8709141985},
#                                {   'close': 23650.19,
#                                    'high': 24683.54,
#                                    'low': 23510.47,
#                                    'open': 23785.01,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 30, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 165519.0,
#                                    'volume': 7101.064772,
#                                    'vwap': 24031.6518664448},
#                                {   'close': 23304.65,
#                                    'high': 24198.18,
#                                    'low': 23232.29,
#                                    'open': 23650.19,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 7, 31, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 211840.0,
#                                    'volume': 5804.269434,
#                                    'vwap': 23696.6816834943},
#                                {   'close': 23275.88,
#                                    'high': 23508.47,
#                                    'low': 22851.9,
#                                    'open': 23308.38,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 1, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 153110.0,
#                                    'volume': 6179.686676,
#                                    'vwap': 23208.445653866},
#                                {   'close': 22990.75,
#                                    'high': 23466.18,
#                                    'low': 22661.29,
#                                    'open': 23275.68,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 2, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 157412.0,
#                                    'volume': 7307.487244,
#                                    'vwap': 23000.7532508123},
#                                {   'close': 22824.55,
#                                    'high': 23638.99,
#                                    'low': 22689.49,
#                                    'open': 22984.53,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 3, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 149283.0,
#                                    'volume': 8164.154704,
#                                    'vwap': 23204.0278109623},
#                                {   'close': 22622.27,
#                                    'high': 23226.61,
#                                    'low': 22404.47,
#                                    'open': 22820.0,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 4, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 144321.0,
#                                    'volume': 7171.334543,
#                                    'vwap': 22877.9995078014},
#                                {   'close': 23317.38,
#                                    'high': 23477.06,
#                                    'low': 22589.01,
#                                    'open': 22622.26,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 5, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 163368.0,
#                                    'volume': 6663.063846,
#                                    'vwap': 23077.2234563133},
#                                {   'close': 22959.28,
#                                    'high': 23355.18,
#                                    'low': 22910.75,
#                                    'open': 23319.06,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 6, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 89788.0,
#                                    'volume': 3220.410148,
#                                    'vwap': 23183.0994354818},
#                                {   'close': 23177.81,
#                                    'high': 23400.0,
#                                    'low': 22854.66,
#                                    'open': 22955.27,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 7, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 71763.0,
#                                    'volume': 2738.6153,
#                                    'vwap': 23100.0175031338},
#                                {   'close': 23816.87,
#                                    'high': 24252.12,
#                                    'low': 23157.35,
#                                    'open': 23176.28,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 8, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 110704.0,
#                                    'volume': 6080.608533,
#                                    'vwap': 23869.8741999964},
#                                {   'close': 23155.85,
#                                    'high': 23931.65,
#                                    'low': 22875.0,
#                                    'open': 23812.12,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 9, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 96149.0,
#                                    'volume': 5809.397123,
#                                    'vwap': 23366.1671925361},
#                                {   'close': 23964.88,
#                                    'high': 24227.11,
#                                    'low': 22659.4,
#                                    'open': 23155.06,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 10, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 136669.0,
#                                    'volume': 7793.976708,
#                                    'vwap': 23542.4480643031},
#                                {   'close': 23940.07,
#                                    'high': 24922.58,
#                                    'low': 23866.8,
#                                    'open': 23964.5,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 11, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 131355.0,
#                                    'volume': 9575.106603,
#                                    'vwap': 24405.5808596467},
#                                {   'close': 24412.39,
#                                    'high': 24466.92,
#                                    'low': 23596.36,
#                                    'open': 23948.03,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 12, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 83287.0,
#                                    'volume': 6708.131073,
#                                    'vwap': 24002.5497691737},
#                                {   'close': 24458.58,
#                                    'high': 24900.55,
#                                    'low': 24295.8,
#                                    'open': 24414.63,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 13, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 69269.0,
#                                    'volume': 6260.78911,
#                                    'vwap': 24562.0682210446},
#                                {   'close': 24315.55,
#                                    'high': 25036.1,
#                                    'low': 24151.07,
#                                    'open': 24458.57,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 14, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 69908.0,
#                                    'volume': 5005.868863,
#                                    'vwap': 24498.8976076202},
#                                {   'close': 24096.82,
#                                    'high': 25214.66,
#                                    'low': 23780.0,
#                                    'open': 24317.93,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 15, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 119697.0,
#                                    'volume': 9307.658862,
#                                    'vwap': 24345.6717362609},
#                                {   'close': 23855.35,
#                                    'high': 24260.97,
#                                    'low': 23676.4,
#                                    'open': 24096.25,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 16, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 91628.0,
#                                    'volume': 7287.205811,
#                                    'vwap': 23950.3131723383},
#                                {   'close': 23335.92,
#                                    'high': 24445.57,
#                                    'low': 23180.0,
#                                    'open': 23858.1,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 17, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 98543.0,
#                                    'volume': 7570.169176,
#                                    'vwap': 23720.664217611},
#                                {   'close': 23198.25,
#                                    'high': 23599.71,
#                                    'low': 23111.22,
#                                    'open': 23338.66,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 18, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 54852.0,
#                                    'volume': 3614.123878,
#                                    'vwap': 23397.0283734063},
#                                {   'close': 20829.32,
#                                    'high': 23207.34,
#                                    'low': 20785.22,
#                                    'open': 23193.46,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 19, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 126064.0,
#                                    'volume': 13898.420049,
#                                    'vwap': 21679.226896266},
#                                {   'close': 21141.95,
#                                    'high': 21363.46,
#                                    'low': 20761.75,
#                                    'open': 20832.79,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 20, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 78657.0,
#                                    'volume': 8426.332255,
#                                    'vwap': 21138.4815452904},
#                                {   'close': 21512.28,
#                                    'high': 21781.64,
#                                    'low': 21067.48,
#                                    'open': 21142.87,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 21, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 68016.0,
#                                    'volume': 6606.500788,
#                                    'vwap': 21389.2946296381},
#                                {   'close': 21397.0,
#                                    'high': 21536.56,
#                                    'low': 20890.32,
#                                    'open': 21511.43,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 22, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 86663.0,
#                                    'volume': 7700.004849,
#                                    'vwap': 21242.1449145144},
#                                {   'close': 21528.61,
#                                    'high': 21679.73,
#                                    'low': 20889.11,
#                                    'open': 21397.0,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 23, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 95921.0,
#                                    'volume': 7192.344421,
#                                    'vwap': 21386.7275029656},
#                                {   'close': 21367.42,
#                                    'high': 21890.76,
#                                    'low': 21147.7,
#                                    'open': 21524.52,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 24, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 80442.0,
#                                    'volume': 8260.057259,
#                                    'vwap': 21502.9757454432},
#                                {   'close': 21558.82,
#                                    'high': 21814.51,
#                                    'low': 21311.63,
#                                    'open': 21367.42,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 25, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 63420.0,
#                                    'volume': 6057.432628,
#                                    'vwap': 21597.3073266794},
#                                {   'close': 20243.48,
#                                    'high': 21872.35,
#                                    'low': 20110.0,
#                                    'open': 21558.36,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 26, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 152067.0,
#                                    'volume': 13095.06348,
#                                    'vwap': 21093.1897276635},
#                                {   'close': 20039.86,
#                                    'high': 20380.32,
#                                    'low': 19800.0,
#                                    'open': 20241.84,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 27, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 83761.0,
#                                    'volume': 8309.563465,
#                                    'vwap': 20102.6660957186},
#                                {   'close': 19552.34,
#                                    'high': 20158.0,
#                                    'low': 19520.19,
#                                    'open': 20038.74,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 28, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 63389.0,
#                                    'volume': 5250.261734,
#                                    'vwap': 19951.6214981557},
#                                {   'close': 20290.0,
#                                    'high': 20419.0,
#                                    'low': 19544.89,
#                                    'open': 19555.69,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 29, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 91779.0,
#                                    'volume': 7323.765069,
#                                    'vwap': 20000.5353625953},
#                                {   'close': 19812.65,
#                                    'high': 20578.0,
#                                    'low': 19541.13,
#                                    'open': 20289.97,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 30, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 114320.0,
#                                    'volume': 9641.439173,
#                                    'vwap': 20048.7201030007},
#                                {   'close': 20060.32,
#                                    'high': 20486.06,
#                                    'low': 19801.13,
#                                    'open': 19812.65,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 8, 31, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 105778.0,
#                                    'volume': 7300.808548,
#                                    'vwap': 20187.103642619},
#                                {   'close': 20132.97,
#                                    'high': 20205.83,
#                                    'low': 19564.86,
#                                    'open': 20051.81,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 1, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 114052.0,
#                                    'volume': 7529.674053,
#                                    'vwap': 19934.7015559282},
#                                {   'close': 19954.16,
#                                    'high': 20444.0,
#                                    'low': 19757.72,
#                                    'open': 20132.5,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 2, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 98745.0,
#                                    'volume': 7392.679014,
#                                    'vwap': 20095.8994413784},
#                                {   'close': 19832.06,
#                                    'high': 20054.69,
#                                    'low': 19658.04,
#                                    'open': 19950.63,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 3, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 52729.0,
#                                    'volume': 3077.135497,
#                                    'vwap': 19839.4065626337},
#                                {   'close': 20002.38,
#                                    'high': 20030.89,
#                                    'low': 19587.86,
#                                    'open': 19834.87,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 4, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 60722.0,
#                                    'volume': 3712.178165,
#                                    'vwap': 19813.5375316233},
#                                {   'close': 19795.12,
#                                    'high': 20058.0,
#                                    'low': 19635.96,
#                                    'open': 19998.77,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 5, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 66396.0,
#                                    'volume': 4817.489036,
#                                    'vwap': 19801.5785916073},
#                                {   'close': 18790.39,
#                                    'high': 20180.5,
#                                    'low': 18668.9,
#                                    'open': 19795.12,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 6, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 139147.0,
#                                    'volume': 11753.830278,
#                                    'vwap': 19480.9863696975},
#                                {   'close': 19290.53,
#                                    'high': 19462.02,
#                                    'low': 18534.06,
#                                    'open': 18789.4,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 7, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 89704.0,
#                                    'volume': 8092.183326,
#                                    'vwap': 18952.4811318379},
#                                {   'close': 19322.54,
#                                    'high': 19457.69,
#                                    'low': 19012.7,
#                                    'open': 19290.53,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 8, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 85298.0,
#                                    'volume': 8670.453356,
#                                    'vwap': 19235.2249945426},
#                                {   'close': 21360.97,
#                                    'high': 21595.12,
#                                    'low': 19293.64,
#                                    'open': 19322.54,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 9, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 142356.0,
#                                    'volume': 13177.780815,
#                                    'vwap': 20768.0608232858},
#                                {   'close': 21650.6,
#                                    'high': 21812.35,
#                                    'low': 21128.39,
#                                    'open': 21365.97,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 10, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 83020.0,
#                                    'volume': 6646.287573,
#                                    'vwap': 21427.5013631818},
#                                {   'close': 21830.0,
#                                    'high': 21866.5,
#                                    'low': 21359.15,
#                                    'open': 21651.59,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 11, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 78930.0,
#                                    'volume': 6563.895242,
#                                    'vwap': 21613.3502193224},
#                                {   'close': 22400.0,
#                                    'high': 22497.58,
#                                    'low': 21543.76,
#                                    'open': 21833.63,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 12, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 158923.0,
#                                    'volume': 10897.080672,
#                                    'vwap': 22112.3930376267},
#                                {   'close': 20173.75,
#                                    'high': 22799.03,
#                                    'low': 19874.92,
#                                    'open': 22397.53,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 13, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 175388.0,
#                                    'volume': 14931.003205,
#                                    'vwap': 21428.6097555905},
#                                {   'close': 20231.0,
#                                    'high': 20533.0,
#                                    'low': 19610.09,
#                                    'open': 20168.82,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 14, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 115205.0,
#                                    'volume': 9937.966735,
#                                    'vwap': 20167.7754849314},
#                                {   'close': 19698.24,
#                                    'high': 20333.8,
#                                    'low': 19500.0,
#                                    'open': 20229.11,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 15, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 117123.0,
#                                    'volume': 10729.864869,
#                                    'vwap': 19973.3112700637},
#                                {   'close': 19800.4,
#                                    'high': 19889.05,
#                                    'low': 19338.0,
#                                    'open': 19705.39,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 16, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 102758.0,
#                                    'volume': 8547.46479,
#                                    'vwap': 19658.4980079077},
#                                {   'close': 20112.04,
#                                    'high': 20191.71,
#                                    'low': 19742.41,
#                                    'open': 19800.4,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 17, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 63058.0,
#                                    'volume': 6930.601187,
#                                    'vwap': 19972.8109750495},
#                                {   'close': 19417.99,
#                                    'high': 20118.74,
#                                    'low': 19333.2,
#                                    'open': 20112.6,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 18, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 107819.0,
#                                    'volume': 7373.686943,
#                                    'vwap': 19776.5602655519},
#                                {   'close': 19540.33,
#                                    'high': 19682.97,
#                                    'low': 18257.92,
#                                    'open': 19421.93,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 19, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 134873.0,
#                                    'volume': 13609.136541,
#                                    'vwap': 19024.1649649258},
#                                {   'close': 18880.27,
#                                    'high': 19637.58,
#                                    'low': 18724.83,
#                                    'open': 19538.66,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 20, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 126457.0,
#                                    'volume': 13247.733095,
#                                    'vwap': 19137.0939999925},
#                                {   'close': 18464.23,
#                                    'high': 19900.0,
#                                    'low': 18168.0,
#                                    'open': 18875.29,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 21, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 180832.0,
#                                    'volume': 19642.803957,
#                                    'vwap': 19089.9793932064},
#                                {   'close': 19403.29,
#                                    'high': 19519.64,
#                                    'low': 18360.98,
#                                    'open': 18464.23,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 22, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 161240.0,
#                                    'volume': 18016.93964,
#                                    'vwap': 18975.5090138431},
#                                {   'close': 19288.36,
#                                    'high': 19498.3,
#                                    'low': 18534.78,
#                                    'open': 19405.29,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 23, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 127292.0,
#                                    'volume': 11672.717883,
#                                    'vwap': 18978.1957350804},
#                                {   'close': 18921.25,
#                                    'high': 19310.2,
#                                    'low': 18810.0,
#                                    'open': 19288.08,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 24, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 71686.0,
#                                    'volume': 6760.587703,
#                                    'vwap': 19074.7639166597},
#                                {   'close': 18809.61,
#                                    'high': 19174.74,
#                                    'low': 18630.86,
#                                    'open': 18925.45,
#                                    'symbol': 'BTC/USD',
#                                    'timestamp': datetime.datetime(2022, 9, 25, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 61643.0,
#                                    'volume': 5927.072745,
#                                    'vwap': 18941.0839816402},
#                                {   'close': 19226.35,
# ...
#                                    'vwap': 4595.0184503686},
#                                {   'close': 4669.4255,
#                                    'high': 4762.879,
#                                    'low': 4609.135,
#                                    'open': 4711.55,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 13, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 145.0,
#                                    'volume': 22.53620928,
#                                    'vwap': 4676.1497063502},
#                                {   'close': 4609.2,
#                                    'high': 4688.9825,
#                                    'low': 4582.625,
#                                    'open': 4672.651,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 14, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 113.0,
#                                    'volume': 12.480208614,
#                                    'vwap': 4647.5291246763},
#                                {   'close': 4525.7,
#                                    'high': 4671.65,
#                                    'low': 4468.0,
#                                    'open': 4611.8,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 15, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 213.0,
#                                    'volume': 9.60605467,
#                                    'vwap': 4515.2496654223},
#                                {   'close': 4502.865,
#                                    'high': 4538.508,
#                                    'low': 4429.1315,
#                                    'open': 4523.025,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 16, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 253.0,
#                                    'volume': 13.980623843,
#                                    'vwap': 4487.760254987},
#                                {   'close': 4592.16,
#                                    'high': 4617.46,
#                                    'low': 4428.0295,
#                                    'open': 4505.13,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 17, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 294.0,
#                                    'volume': 14.381364915,
#                                    'vwap': 4485.1431051001},
#                                {   'close': 4589.83,
#                                    'high': 4644.505,
#                                    'low': 4555.66,
#                                    'open': 4596.1595,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 18, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 129.0,
#                                    'volume': 14.292153896,
#                                    'vwap': 4601.4120229128},
#                                {   'close': 4471.1,
#                                    'high': 4622.25,
#                                    'low': 4438.9525,
#                                    'open': 4592.173,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 19, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 89.0,
#                                    'volume': 5.843069432,
#                                    'vwap': 4496.6187833338},
#                                {   'close': 4483.655,
#                                    'high': 4510.9,
#                                    'low': 4456.85,
#                                    'open': 4472.836,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 20, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 74.0,
#                                    'volume': 3.309568442,
#                                    'vwap': 4478.4901784142},
#                                {   'close': 4448.6485,
#                                    'high': 4498.8645,
#                                    'low': 4446.3,
#                                    'open': 4482.636,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 21, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 72.0,
#                                    'volume': 6.809227484,
#                                    'vwap': 4478.488325856},
#                                {   'close': 4203.955,
#                                    'high': 4458.001,
#                                    'low': 4075.295,
#                                    'open': 4446.062,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 22, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 487.0,
#                                    'volume': 96.489178511,
#                                    'vwap': 4157.2113841543},
#                                {   'close': 4166.625,
#                                    'high': 4231.4525,
#                                    'low': 4119.8735,
#                                    'open': 4206.4,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 23, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 226.0,
#                                    'volume': 69.064155031,
#                                    'vwap': 4192.7881082885},
#                                {   'close': 4155.109,
#                                    'high': 4206.685,
#                                    'low': 4077.65875,
#                                    'open': 4165.09,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 24, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 177.0,
#                                    'volume': 19.992621829,
#                                    'vwap': 4171.016880013},
#                                {   'close': 3874.635,
#                                    'high': 4161.6585,
#                                    'low': 3825.776,
#                                    'open': 4152.8125,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 25, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 417.0,
#                                    'volume': 97.562403456,
#                                    'vwap': 3959.3762587673},
#                                {   'close': 4035.311,
#                                    'high': 4067.39,
#                                    'low': 3869.99,
#                                    'open': 3876.403,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 26, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 314.0,
#                                    'volume': 72.549349119,
#                                    'vwap': 3965.0218614204},
#                                {   'close': 4019.85,
#                                    'high': 4041.3035,
#                                    'low': 3974.9975,
#                                    'open': 4037.97,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 27, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 106.0,
#                                    'volume': 10.178207235,
#                                    'vwap': 4002.955493424},
#                                {   'close': 4144.86,
#                                    'high': 4147.3,
#                                    'low': 3968.2525,
#                                    'open': 4021.779,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 28, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 106.0,
#                                    'volume': 12.273315814,
#                                    'vwap': 3999.5033883044},
#                                {   'close': 4217.556,
#                                    'high': 4238.2,
#                                    'low': 4085.925,
#                                    'open': 4147.115,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 29, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 191.0,
#                                    'volume': 17.56409386,
#                                    'vwap': 4157.2828991302},
#                                {   'close': 4146.85,
#                                    'high': 4242.31,
#                                    'low': 4093.4655,
#                                    'open': 4220.862,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 9, 30, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 192.0,
#                                    'volume': 19.451051351,
#                                    'vwap': 4147.7854736692},
#                                {   'close': 4350.17,
#                                    'high': 4357.217,
#                                    'low': 4124.39,
#                                    'open': 4149.16,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 1, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 228.0,
#                                    'volume': 30.494196067,
#                                    'vwap': 4318.0618128104},
#                                {   'close': 4488.005,
#                                    'high': 4519.6095,
#                                    'low': 4335.4605,
#                                    'open': 4352.04,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 2, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 214.0,
#                                    'volume': 45.749028474,
#                                    'vwap': 4415.9831002661},
#                                {   'close': 4516.243,
#                                    'high': 4594.47,
#                                    'low': 4431.036,
#                                    'open': 4490.71,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 3, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 228.0,
#                                    'volume': 49.837002385,
#                                    'vwap': 4512.555713661},
#                                {   'close': 4489.5885,
#                                    'high': 4521.01,
#                                    'low': 4442.685,
#                                    'open': 4514.601,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 4, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 141.0,
#                                    'volume': 11.848565473,
#                                    'vwap': 4489.2756748003},
#                                {   'close': 4515.068,
#                                    'high': 4618.2431700505,
#                                    'low': 4469.5355,
#                                    'open': 4490.026,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 5, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 113.0,
#                                    'volume': 28.159820485,
#                                    'vwap': 4540.1889137144},
#                                {   'close': 4685.297,
#                                    'high': 4740.5,
#                                    'low': 4491.2755,
#                                    'open': 4513.7435,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 6, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 277.0,
#                                    'volume': 79.604341788,
#                                    'vwap': 4650.182086402},
#                                {   'close': 4449.89,
#                                    'high': 4757.935,
#                                    'low': 4434.74,
#                                    'open': 4689.194,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 7, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 270.0,
#                                    'volume': 29.389866673,
#                                    'vwap': 4595.614515882},
#                                {   'close': 4525.59,
#                                    'high': 4558.63,
#                                    'low': 4416.9804988396,
#                                    'open': 4447.7,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 8, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 173.0,
#                                    'volume': 17.827679547,
#                                    'vwap': 4490.5174145844},
#                                {   'close': 4368.1675,
#                                    'high': 4534.4,
#                                    'low': 4267.401,
#                                    'open': 4528.28,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 9, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 291.0,
#                                    'volume': 63.614829949,
#                                    'vwap': 4355.4864133449},
#                                {   'close': 3834.675,
#                                    'high': 4395.658,
#                                    'low': 3505.525,
#                                    'open': 4370.815,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 10, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 527.0,
#                                    'volume': 146.416019901,
#                                    'vwap': 3959.097333001},
#                                {   'close': 3751.355,
#                                    'high': 3886.9635,
#                                    'low': 3651.691,
#                                    'open': 3833.235,
#                                    'symbol': 'ETH/USD',
#                                    'timestamp': datetime.datetime(2025, 10, 11, 0, 0, tzinfo=TzInfo(0)),
#                                    'trade_count': 473.0,
#                                    'volume': 119.389301789,
#                                    'vwap': 3799.1294877255}]}}

# %%
from alpaca.data import CryptoHistoricalDataClient, StockHistoricalDataClient, OptionHistoricalDataClient

# no keys required.
crypto_client = CryptoHistoricalDataClient()

# keys required
stock_client = StockHistoricalDataClient("api-key",  "secret-key")
option_client = OptionHistoricalDataClient("api-key",  "secret-key")

# %%
from alpaca.trading import TradingClient, MarketOrderRequest, TimeInForce, OrderSide
import os
from dotenv import load_dotenv
load_dotenv()  # 会自动读取当前目录的 .env 文件

api_key = os.getenv("APCA_API_KEY_ID")
api_secret = os.getenv("APCA_API_SECRET_KEY")
base_url = os.getenv("APCA_API_BASE_URL")

client = TradingClient(api_key, api_secret, paper=True)

order = MarketOrderRequest(
    symbol="AAPL",
    qty=1,
    side=OrderSide.BUY,
    time_in_force=TimeInForce.DAY,
)

resp = client.submit_order(order)
print(resp)
# Out:
# id=UUID('fa854a2d-afdd-4ee9-a5a3-d1e5d4ee34f5') client_order_id='b34155a3-dfbf-4e55-806c-fc7090955aa4' created_at=datetime.datetime(2025, 10, 12, 22, 49, 57, 288276, tzinfo=TzInfo(0)) updated_at=datetime.datetime(2025, 10, 12, 22, 49, 57, 291069, tzinfo=TzInfo(0)) submitted_at=datetime.datetime(2025, 10, 12, 22, 49, 57, 288276, tzinfo=TzInfo(0)) filled_at=None expired_at=None expires_at=datetime.datetime(2025, 10, 13, 20, 0, tzinfo=TzInfo(0)) canceled_at=None failed_at=None replaced_at=None replaced_by=None replaces=None asset_id=UUID('b0b6dd9d-8b9b-48a9-ba46-b9d54906e415') symbol='AAPL' asset_class=<AssetClass.US_EQUITY: 'us_equity'> notional=None qty='1' filled_qty='0' filled_avg_price=None order_class=<OrderClass.SIMPLE: 'simple'> order_type=<OrderType.MARKET: 'market'> type=<OrderType.MARKET: 'market'> side=<OrderSide.BUY: 'buy'> time_in_force=<TimeInForce.DAY: 'day'> limit_price=None stop_price=None status=<OrderStatus.ACCEPTED: 'accepted'> extended_hours=False legs=None trail_percent=None trail_price=None hwm=None position_intent=<PositionIntent.BUY_TO_OPEN: 'buy_to_open'> ratio_qty=None

# %%
from alpaca.trading import LimitOrderRequest

# Create a limit order: Buy 1 share of Netflix at $280 or better
order = LimitOrderRequest(
    symbol="NFLX",
    qty=1,
    side=OrderSide.BUY,
    limit_price=260.00,
    time_in_force=TimeInForce.DAY,  # expires end of trading day
)

placed = client.submit_order(order)

# %%
orders = client.get_orders()
print(orders)
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b0b6dd9d-8b9b-48a9-ba46-b9d54906e415'),
#     'canceled_at': None,
#     'client_order_id': 'b34155a3-dfbf-4e55-806c-fc7090955aa4',
#     'created_at': datetime.datetime(2025, 10, 12, 22, 49, 57, 288276, tzinfo=TzInfo(0)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 10, 13, 20, 0, tzinfo=TzInfo(0)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('fa854a2d-afdd-4ee9-a5a3-d1e5d4ee34f5'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': '1',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.ACCEPTED: 'accepted'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 10, 12, 22, 49, 57, 288276, tzinfo=TzInfo(0)),
#     'symbol': 'AAPL',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 10, 12, 22, 49, 57, 291069, tzinfo=TzInfo(0))}]

# %% [markdown]
# ---
#
# # 通用 Prompt（含 MUST / MUST NOT，分场景）
#
# ## 0) 角色与目标
#
# * **你是**：一名可靠的技术与金融讲解助手，输出要结构化、可执行、可验证。
# * **目标**：在不丢失关键信息的前提下，给出“本质解释 + 使用套路 + 可跑示例/清单化要点”。
# * **语言风格**： 你的目的是让我懂， 而不是说套话， 所以语言风格保持专业性的情况下尽可能低俗， 通俗
#
# ---
#
# ## 1) 全局 MUST / MUST NOT
#
# ### MUST
#
# 1. **结构固定**：按以下顺序输出
#    * 背景与目的
#    * 本质与类比
#    * 使用套路与场景
#    * 示例与可运行用例（若是编程，给单元测试；若是金融教材，给要点清单与小结）
#    * 注意点与常见坑
#    * 若有过时方案：提供**现代替代**与迁移建议
# 2. **信息保真**：用户贴的材料不得遗漏关键前提、定义、公式或结论。若省略，需列“被省略项”。
# 3. **说清“不然会怎样”**：每个关键概念都要说明误用后果或边界条件。
# 4. **对比 Python**：讲代码/语法时，能对比 Python 的就对比。
# 5. **示例真实场景**：示例基于现实业务或合理模拟，不要空洞玩具例子。
# 6. **术语一致**：同一概念名词全篇一致；若存在别名，首次出现时并列。
# 7. **若用户方案已过时**：显式标注“过时”，给出现代优雅替代方案与迁移步骤。
# 8. **最新 API 优先**：讲解编程接口时优先使用主流、稳定、最新版本。
# 9. **可执行性**：给出的代码必须可直接粘贴运行（含依赖与断言），给出环境或版本说明。
# 10. **时间敏感**：若涉及日期/规则，输出中给出**具体日期或版本号**以避免歧义。
#
# ### MUST NOT
#
# 1. 不输出大段文档式堆砌；禁止空话和重复定义。
# 2. 不使用过时 API 或不推荐做法，除非用于对比，并明确标注“仅为历史背景，勿在生产使用”。
# 3. 不给与主题无关的延伸，不写与事实冲突的猜测。
# 4. 不输出不可运行/缺依赖的示例。
# 5. 不复刻受版权保护的大段原文或歌词。
# 6. 不用含糊词汇：“可能、也许、看情况”之类必须配条件与判断准则。
#
# ---
#
# ## 2) 场景 A：金融教材讲解模式
#
# **输入**：`<整段教材粘贴>`
#
# **输出要求（MUST）**
#
# * **背景与目的**：教材片段处在什么章节/体系里，解决什么问题。
# * **关键定义/符号/公式**：逐条列出，不得缺失。
# * **推导与直觉**：用最短链路解释每步推导的“为什么”，给风险或假设。
# * **应用场景**：列出3类常见实务应用与数据前置条件。
# * **扩展总结**：提炼成决策清单或流程图文字版。
# * **注意点**：至少2条常见误解与规避做法。
# * **若有过时内容**：给出现代替代方法及迁移指引（工具、数据、指标或模型）。
#
# **输出示例骨架**
#
# * 背景与目的：…
# * 本质与类比：…
# * 要点清单：1) … 2) …
# * 应用与数据要求：…
# * 常见坑：…
# * 现代替代/补充：…
# * 小结：…
#
# ---
#
# ## 3) 场景 B：代码知识点/语法/关键字讲解模式
#
# **输出要求（MUST）**
#
# * **本质**：这玩意儿到底在指挥机器干什么。
# * **与 Python 的类比**：指出对应语法/库/惯用法。
# * **使用套路**：3 个最常见场景的“判断条件 → 选择此法”。
# * **不然会怎样**：误用后的行为、性能或一致性后果。
# * **最新 API**：如旧法已不推荐，给出现代用法并说明兼容点。
# * **可运行单测**：提供可直接粘贴进 IDE 运行的单测或最小可复现实例，包含断言。
# * **环境声明**：语言/框架/依赖版本。
#
# ---
#
# ## 4) 场景 C：示例需求（统一规范）
#
# **输入**：`<你要的例子主题>`
#
# **输出要求（MUST）**
#
# * **真实业务背景**：一句话说明场景来源与目标。
# * **数据或前置**：需要哪些输入、边界值、环境。
# * **最小可运行体**：可复制执行的代码/命令/SQL，含断言或可见输出。
# * **结果核对**：预期输出或校验条件。
# * **坑点**：1 至 2 条。
#
# ---
#
# ## 5) 场景 D：德语讲解模式
#
# **输入**：`<德语句子/语法点/长词>`
#
# **输出要求（MUST）**
#
# * **拆句**：把长句切成短句，逐句解释语序与功能。
# * **拆词**：把长单词拆成词根/前后缀，说明记忆法。
# * **英语类比**：用英语句型或语序做对比帮助理解。
# * **口语与缩略**：给出德国人日常口语/省略说法，并说明何时使用。
# * **练习**：至少1条替换练习句。
# * **保留口语学习定位**：不讲格变细节，专注开口表达与固定搭配。
#
# **输出骨架**
#
# * 原句：…
# * 拆句讲解：1) … 2) …
# * 拆词与记忆：…
# * 英语类比：…
# * 口语表达：…
# * 练习：…
